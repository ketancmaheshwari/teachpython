# %%
# int float string Bool None

# A collection of data items
# lists -- collection of data items in one variable
# create list, items separated by comma in square brackets
groceries = ["milk", "salt", "sugar", "bread", "rice", "cumin"] # square brackets

#         0  1  2  3  4    5   6
primes = [2, 3, 5, 7, 11, 13, 17] #list of first few prime numbers
#         -7 -6 -5 -4  -3 -2  -1

# printing entire list
#print(groceries)
#print(primes)
#print(type(primes))

mix_items = ["cat", 14, False, None, 3.1415]

#print(mix_items)

# list index -- starts with 0!
#print(groceries[0])


# printing individual elements of list
#print(groceries[5])
#print(mix_items[2])
#print(primes[3])

# Counting from end
#print(groceries[-1])

# Length of a list using len function
#print(len(primes))

# Changing a value in a list
groceries[3] = "oil"
#print(groceries)

# Deleting an item from list by index using del
del groceries[4]
#print(groceries)

# Running over the index limit of a  list
#print(primes[10])
#print(primes[-12])

# Appending to a list with .append function
primes.append(19)
#print(primes)

# reversing a list with .reverse function
primes.reverse()
#print(primes)

# inserting into a list with .insert(index, "item") function
mix_items = ["cat", 14, False, None, 3.1415]
#print(mix_items)
mix_items.insert(0, "dog")
#print(mix_items)
mix_items.insert(4, True)
#print(mix_items)

# Remove by value with .remove("item")
mix_items.remove("cat")
#print(mix_items)
#mix_items.remove("mouse") # should give error because item not in list

# Sorting temporary with sorted() function
#print(primes)
#print(sorted(primes))
#print(primes)

# Sorting permanently with the .sort() function
primes.sort()
#print(primes)

# Concatenate with + operator
first_students = ["Ron", "John", "Dave"]
new_students = ["Mira", "Sona", "Anu"]

all_students = first_students + new_students

all_students = ["Ron", "John", "Dave"] + ["Mira", "Sona", "Anu"]

all_students += ["Raj", "Ravi"]

#print(all_students)

# Is the item in the list? 'x' in list -- a boolean expression - gives True / False
#print("Ravi" not in all_students)
#print("Greg" in all_students)

if "John" in all_students:
    print("John is included.")
else:
    print("John is missing.")
# Out:
# John is included
